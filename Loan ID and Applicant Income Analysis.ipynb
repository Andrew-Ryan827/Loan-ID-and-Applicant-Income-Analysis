# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
#data = p.d_read_csv('path/to/file')
data = pd.read_csv('C:/Users/Chidi Ryan/Documents/Data_Analysis/df1_loan.csv')

data.head()
data.tail()
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents     Education  \
# 495         495  LP002586  Female     Yes          1      Graduate
# 496         496  LP002587    Male     Yes          0  Not Graduate
# 497         497  LP002588    Male     Yes          0      Graduate
# 498         498  LP002600    Male     Yes          1      Graduate
# 499         499  LP002602    Male      No          0      Graduate
#
#     Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 495            No             3326              913.0       105.0
# 496            No             2600             1700.0       107.0
# 497            No             4625             2857.0       111.0
# 498           Yes             2895                0.0        95.0
# 499            No             6283             4416.0       209.0
#
#      Loan_Amount_Term  Credit_History Property_Area Loan_Status Total_Income
# 495              84.0             1.0     Semiurban           Y      $4239.0
# ...

# %%
loan = data[(data['ApplicantIncome'] >= 10000)]

loan.count()
# Out:
# Unnamed: 0           45
# Loan_ID              45
# Gender               42
# Married              44
# Dependents           43
# Education            45
# Self_Employed        43
# ApplicantIncome      45
# CoapplicantIncome    45
# LoanAmount           42
# Loan_Amount_Term     45
# Credit_History       44
# Property_Area        45
# Loan_Status          45
# Total_Income         45
# dtype: int64

# %%
loan.head()
# Out:
#      Unnamed: 0   Loan_ID  Gender Married Dependents Education Self_Employed  \
# 9             9  LP001020    Male     Yes          1  Graduate            No
# 34           34  LP001100    Male      No         3+  Graduate            No
# 54           54  LP001186  Female     Yes          1  Graduate           Yes
# 67           67  LP001233    Male     Yes          1  Graduate            No
# 102         102  LP001350    Male     Yes        NaN  Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 9              12841            10968.0       349.0             360.0
# 34             12500             3000.0       320.0             360.0
# 54             11500                0.0       286.0             360.0
# 67             10750                0.0       312.0             360.0
# 102            13650                0.0         NaN             360.0
#
#      Credit_History Property_Area Loan_Status Total_Income
# ...

# %%
ID = loan['Loan_ID']
ID
# Out:
# 9      LP001020
# 34     LP001100
# 54     LP001186
# 67     LP001233
# 102    LP001350
# 106    LP001369
# 115    LP001401
# 119    LP001422
# 126    LP001448
# 128    LP001451
# 130    LP001469
# 138    LP001492
# 144    LP001508
# 146    LP001516
# 148    LP001519
# 155    LP001536
# 171    LP001585
# 183    LP001637
# 185    LP001640
# 191    LP001656
# 199    LP001673
# 210    LP001708
# 254    LP001844
# 258    LP001859
# 271    LP001891
# 278    LP001907
# 284    LP001922
# 308    LP001996
# 319    LP002050
# 324    LP002065
# 333    LP002101
# 369    LP002191
# 370    LP002194
# 409    LP002317
# 424    LP002364
# 432    LP002386
# 435    LP002393
# 438    LP002403
# 443    LP002422
# 467    LP002501
# 475    LP002527
# 478    LP002531
# 483    LP002541
# 487    LP002547
# 493    LP002582
# Name: Loan_ID, dtype: object

# %%
Income = loan['ApplicantIncome']
Income
# Out:
# 9      12841
# 34     12500
# 54     11500
# 67     10750
# 102    13650
# 106    11417
# 115    14583
# 119    10408
# 126    23803
# 128    10513
# 130    20166
# 138    14999
# 144    11757
# 146    14866
# 148    10000
# 155    39999
# 171    51763
# 183    33846
# 185    39147
# 191    12000
# 199    11000
# 210    10000
# 254    16250
# 258    14683
# 271    11146
# 278    14583
# 284    20667
# 308    20233
# 319    10000
# 324    15000
# 333    63337
# 369    19730
# 370    15759
# 409    81000
# 424    14880
# 432    12876
# 435    10047
# 438    10416
# 443    37719
# 467    16692
# 475    16525
# 478    16667
# 483    10833
# 487    18333
# 493    17263
# Name: ApplicantIncome, dtype: int64

# %%
plt.figure(figsize=(20, 5))
plt.bar(ID, Income, color=['purple'])
plt.xticks(rotation=30)
plt.title('Loan Analysis of Loan_ID and ApplicantIncome')
plt.show()
